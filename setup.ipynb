# %% [markdown]
# Introduction to Stanfoedkarel

# %% [markdown]
# 1. Setup

# %%
from stanfordkarel import *
print('Karel library imported successfully!')
# Out:
# Karel library imported successfully!
