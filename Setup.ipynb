# %% [markdown]
# # PROBABILITY & STATS ASSIGNMENT ONE
# ## DESCRIPTIVE STATS
# ### MUGANGA CHARLES

# %% [markdown]
# $\frac{1}{N} \sum_{n-1}^{n} x$

# %%
2-1
# Out:
# 1

# %% [markdown]
# - The result from the cell above is `1`, and a positive value.
