# %% [markdown]
# LAKAREBER JULIET LAURA
# B41236
# S26B38-069

# %% [markdown]
# #Approaches to reading data
# 1. We shoukd know the extension of the file e.g xls, xlsx, csv, json etc.
# 2. We tell where the file is located eg;
# - in the same folder with the notebook
# - in in another folder/dir

# %%
import pandas as pd

# %% [markdown]
# ## reading the dataset
# student_data = pd.read_csv()
# student_data

# %%
## location: in the same folder is that we write the same file name
student_data = pd.read_csv('StudentsPerformance.csv')
student_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ## location: in the same folder is that we write the same file name
# ----> 2 student_data = pd.read_csv('StudentsPerformance.csv')
#       3 student_data
#
# NameError: name 'pd' is not defined

# %%
student_data.shape
# Out:
# (1000, 8)

# %%
student_data.head() ##
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
student_data.head(10) ##
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
student_data.tail() ##
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
student_data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='str')

# %%
student_data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
student_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   str
#  1   race/ethnicity               1000 non-null   str
#  2   parental level of education  1000 non-null   str
#  3   lunch                        1000 non-null   str
#  4   test preparation course      1000 non-null   str
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), str(5)
# memory usage: 62.6 KB

# %% [markdown]
# 1. Find the mean math score?
# 2. what is the median reading score?
# 3. What is the modal writing score?
# 4. Find the average maths score for females?
# 5. Construct a new column called 'Total (summation of math reading and writing ascore) and find its average

# %% [markdown]
# 1. Mean math score.

# %%
mean_math_score = student_data['math score'].mean() ## mean of math score
mean_math_score
# Out:
# np.float64(66.089)

# %% [markdown]
# The mean math score of math is 66.089

# %% [markdown]
# 2. Median reading score.

# %%
median_reading_score = student_data['reading score'].median() ## median of reading score
median_reading_score
# Out:
# np.float64(70.0)

# %% [markdown]
# The median of reading score is 70.0

# %% [markdown]
# 3. Modal writing score.

# %%
modal_writing_score = student_data['writing score'].mode() ## mode of writing score
modal_writing_score
# Out:
# 0    74
# Name: writing score, dtype: int64

# %% [markdown]
# The modal wrting score is 74

# %% [markdown]
# 4. average maths score for females.

# %%
female_student = student_data[student_data['gender']=='female']
female_student['math score'].mean()
# Out:
# np.float64(63.633204633204635)

# %% [markdown]
# - From the results the average for female students is 63.6332.

# %% [markdown]
# 5. Total_marks for reading, math and writing score.

# %%
student_data['total marks']= student_data['math score'] + student_data['reading score'] + student_data['writing score']
student_data['total marks']
student_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
student_data['total marks'].mean()
# Out:
# np.float64(203.312)

# %% [markdown]
# - From the results above the mean total score is 203.312.

# %% [markdown]
# Average of the total_marks.

# %%
Average = Total_students.mean() 
Average
# Out:
# np.float64(203.312)

# %% [markdown]
# The average of the total_marks is 203.312.

# %% [markdown]
# Measures Of Position.

# %% [markdown]
# [[1/4], [2/4], [3/4], [4/4]]
# [[0.25], [0.5], [0.75], [1.0]]

# %%
lower_quartile = student_data['math score'].quantile(0.25) ## lower quartile
lower_quartile
# Out:
# np.float64(57.0)

# %%
upper_quartile = student_data['math score'].quantile(0.75) ## upper quartile

# %%
import numpy as np

ninty_per = np.percentile(student_data['math score'], 90) ##  90th percentile
ninty_per
# Out:
# np.float64(86.0)

# %% [markdown]
# student_data = pd.read_xlsx()

# %%
## location: outside the folder
student_data = pd.read_excel("C:\\Users\\LENOVO\\OneDrive\\Documents\\StudentsPerformance.xlsx")
student_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# [[1/4],[2/4],[3/4],[4/4]] [[0.25],[0.5],[0.75],[1.0]]

# %%
inter_quartile = student_data['math score'].quantile (0.75) - student_data['math score'].quantile (0.25)
inter_quartile

# %% [markdown]
# student_data = pd.read_xlsx()

# %%
import pandas as pd
## location: in the same folder
student_data = pd.read_excel("C:\\Users\\LENOVO\\OneDrive\\Desktop\\PROBABILITY\\daddy.xlsx")
student_data
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]
