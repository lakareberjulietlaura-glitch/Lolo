# %% [markdown]
# 1. Using the Boolean DataType (True or False).

# %%
x=10
y=5 
print(x==y)
print(x>=y) 
print(y==7)
print(y)
# Out:
# False
# True
# False
# 5

# %% [markdown]
# 2. Using the "If Statement".

# %%
Test1 =eval(input("Enter Score in Test-I:"))
Test2 =eval(input("Enter Score in Test-II:"))
Test3 =eval(input("Enter Score in Test-III"))
avg = (Test1+Test2+ Test3)/3
print("Your Average Score is :", avg)
if avg>=90:
    print("Congralutions on a high Average!")
# Out:
# Your Average Score is : 89.33333333333333

# %%
X =eval(input("Enter a number:"))
if (X>0):
    print("X is a positive")
    print("Positive numbers are great!")
    print("Thanks for your time.")
# Out:
# X is a positive
# Positive numbers are great!
# Thanks for your time.

# %% [markdown]
# 3. Using Multiple If Statement.

# %%
X =eval(input("Enter a number:"))
if (X%2==0):
    print("Entered number is Even")
if (X%2!=0):
    print("Entered a number is Odd")
# Out:
# Entered number is Even

# %%
X =eval(input("Enter a number:"))
if (X%2==0):
    print("Entered number is Even")
if (X%2!=0):
    print("Entered a number is Odd")
# Out:
# Entered a number is Odd

# %% [markdown]
# If-Else Statement.

# %%
X =eval(input("Enter a number:"))
if (X>=0):
    print("X is a positive")
    print("Positive numbers are great!")
else:
    print("X is a negative")
    print("Negative numbers are scary!")
print("Thanks for your time.")
# Out:
# X is a positive
# Positive numbers are great!
# Thanks for your time.

# %%
X =eval(input("Enter a number:"))
if (X>=0):
    print("X is a positive")
    print("Positive numbers are great!")
else:
    print("X is a negative")
    print("Negative numbers are scary!")
print("Thanks for your time.")
# Out:
# X is a negative
# Negative numbers are scary!
# Thanks for your time.

# %% [markdown]
# #TASKS:
# TASK 1.

# %%
X =eval(input("Enter a number:"))
if (X%2==0):
    print("Entered number is Even")
if (X%2!=0):
    print("Entered a number is Odd")
# Out:
# Entered number is Even

# %% [markdown]
# TASK 2.

# %%
length_cm = float(input("Enter length in centimeters: "))
if length_cm<0:
    print("Invalid entry. Length cannot be negative.")
else:
    length_inches = (length_cm)/2.54
    print("Length in inches:", length_inches)
# Out:
# Length in inches: 3.937007874015748

# %% [markdown]
# TASK 3.

# %%
First = float(input("Enter First number:"))
Second = float(input("Enter Second number:"))
if abs(First-Second)<=10:
    print("Entered numbers are closed!")
else:
    print("Entered numbers are Not Closed!")
# Out:
# Entered numbers are closed!

# %% [markdown]
# TASK 4.

# %%
hour = int(input("Enter an hour between 1 and 12: "))
period = input("Enter am or pm: ")
if period == "am":
    if hour == 12:
        hour = 0
else:
    if hour != 12:
        hour = hour + 12
print("24-hour format:", hour)
# Out:
# 24-hour format: 16

# %%
hour = int(input("Enter an hour between 1 and 12: "))
period = input("Enter am or pm: ")
if period == "am":
    if hour == 12:
        hour = 0
else:
    if hour != 12:
        hour = hour + 12
print("24-hour format:", hour)
# Out:
# 24-hour format: 22

# %% [markdown]
# TASK 5.

# %%
import math
number = float(input("Enter a number: "))
if number >= 0:
    result = math.sqrt(number)
    print("Square root is:", result)
else:
    number = number * -1
    result = math.sqrt(number)
    print("Square root is:", result, "j")
# Out:
# Square root is: 6.0

# %%
import math
number = float(input("Enter a number: "))
if number >= 0:
    result = math.sqrt(number)
    print("Square root is:", result)
else:
    number = number * -1
    result = math.sqrt(number)
    print("Square root is:", result, "j")
# Out:
# Square root is: 5.0 j

# %% [markdown]
# TASK 6.

# %%
a = eval(input("Enter first number: "))
b = eval(input("Enter second number: "))
if b ==0:
    print("Division by zero is not possible!")
else:
    ratio = a / b
    print("Ratio of two numbers is:", ratio)
# Out:
# Ratio of two numbers is: 2.0

# %% [markdown]
# TASK 7.

# %%
import math

number = int(input("Enter a number: "))
if number < 0:
    print (f"{number} is not a perfect_square.")
else:
    root = math.isqrt(number)
    if root * root == number:
        print(f"{number} is a perfect square.")
    else:
        print(f"{number} is not a perfect square.")
# Out:
# 16 is a perfect square.

# %% [markdown]
# TASK 8.

# %%
Subject1 = eval(input('Enter Score in Subject-I :'))
Subject2 = eval(input('Enter Score in subject-II :'))
Subject3 = eval(input('Enter Score in subject-III :'))
Subject4 = eval(input('Enter Score in subject-IV :'))
Subject5 = eval(input('Enter Score in subject-V :'))
avg = (Subject1 + Subject2 +Subject3 +Subject4 +Subject5)/5
print ('Your Average Score is:', avg)
if avg>=80:
    print ('You are an outstanding student')
if avg>=70 and avg<80:
    print('You are a good student')
if avg>=60 and avg<70:
    print('You are an average student')
if avg>=50 and avg<60:
    print('You are a below-average student') 
if avg>=40 and avg<50:
    print('You are a poor student')   
if avg<40:
    print('You need extra ordinary efforts')
# Out:
# Your Average Score is: 79.6
# You are a good student

# %% [markdown]
# TASK 9.

# %%
import math

a = eval(input("Enter first side: "))
b = eval(input("Enter second side: "))
c = eval(input("Enter third side: "))
if a+b>c and a+c>b and b+c>a:
    s = (a + b + c) / 2
    area = math.sqrt(s * (s - a) * (s- b) * (s - c))
    print("Area of the triangle is:", area)
else:
    print(" The triangle is invalid!")
# Out:
# Area of the triangle is: 6.0

# %% [markdown]
# TASK 10.

# %%
Number1 = int(input("Enter first number-I: "))
Number2 = int(input("Enter second number-II: "))
Number3 = int(input("Enter  third number-III: "))
Maximum = Number1
if Number2 > Maximum:
    Maximum = Number2
if  Number3 > Maximum:
    Maximum = Number3
if Maximum ==Number1:
    print(Number1, "is the largest")
if Maximum == Number2:
    print(Number2, "is the largest")
if Maximum == Number3:
    print(Number3, "is the largest")
# Out:
# 14 is the largest

# %% [markdown]
# TASK 11.

# %%
Marital_status = input("Enter Marital_status (married/unmarried): ")
Gender = input("Enter Gender (male/female: )")
Age = int(input("Enter age: "))
if Marital_status == "marrried":
    print("You are eligible for insurance.")
elif Marital_status == "unmarried" and Gender == "male" and Age > 30:
 print("You are eligible for insurance.")
elif Marital_status == "unmarried" and Gender == "female" and Age > 25:
   print("You are eligible for insurance.")
else:
   print("You are not eligible for insurance.")
# Out:
# You are eligible for insurance.
